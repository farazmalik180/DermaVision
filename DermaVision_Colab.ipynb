# %% [markdown]
# # DermaVision GPU Training (Google Colab / Kaggle)
#
# This notebook allows you to train your model in ~20 minutes using a free cloud GPU.
#
# ### Instructions:
# 1. Open this notebook in [Google Colab](https://colab.research.google.com/).
# 2. In the top menu, go to **Runtime > Change runtime type** and select **T4 GPU**.
# 3. In Colab's left menu, click the **Folder icon** and click the 'New Folder' button to create a folder named `backend`.
# 4. Upload only your `train.py` and `model.py` files directly into that new `backend` folder.
# 5. Run the cells below one by one!

# %%
# 1. Setup Kaggle API and download the dataset directly to the Colab machine
# !pip install -q kaggle torch torchvision pandas numpy scikit-learn tqdm grad-cam

# !mkdir -p ~/.kaggle
# !echo '{"username":"muhammadfarazmalik","key":"KGAT_78dcdc99cc7a825e3eadeaf98eb2bf7c"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# !mkdir -p backend/data
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000 -p backend/data
# !unzip -q backend/data/skin-cancer-mnist-ham10000.zip -d backend/data/
# !rm backend/data/skin-cancer-mnist-ham10000.zip

# %%
# 2. Run the training script (it will automatically detect and use the GPU!)
# !python backend/train.py

# %% [markdown]
# ## ✅ Finished!
# Once the training completes, refresh the file browser on the left, download `backend/model.pth`, and place it in your local `backend` folder.
