# %%
pip install grad-cam kaggle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 104.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44285 sha256=116753934f4b9fcd2aeff406eba331bb03de9343ce5a0a0702060d26f85afc96
#   Stored in directory: /root/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
# Successfully built grad-cam
# ...

# %%
# 1. Clean up any previous messy folders
# !rm -rf /content/DermaVision
# Ensure we are in /content before cloning
# %cd /content
# 2. Clone the repository (this automatically pulls the overfitting fixes we made!)
# !git clone https://github.com/farazmalik180/DermaVision.git
# Now change into the cloned directory
# %cd /content/DermaVision
# 3. Setup Kaggle API
# !pip install -q kaggle torch torchvision pandas numpy scikit-learn tqdm grad-cam
# !mkdir -p ~/.kaggle
# !echo '{"username":"muhammadfarazmalik","key":"KGAT_78dcdc99cc7a825e3eadeaf98eb2bf7c"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# 4. Download and unzip the dataset directly into backend/data
# !mkdir -p backend/data
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000 -p backend/data
# !unzip -q backend/data/skin-cancer-mnist-ham10000.zip -d backend/data/
# !rm backend/data/skin-cancer-mnist-ham10000.zip
# 5. Start the upgraded training process!
# !python backend/train.py
# 6. Automatically trigger download of the model when finished!
from google.colab import files
import os
if os.path.exists('/content/DermaVision/backend/model.pth'):
    print("Training complete! Downloading model to your computer...")
    files.download('/content/DermaVision/backend/model.pth')
else:
    print("Training failed or was interrupted. Model not found.")
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /content
# Cloning into 'DermaVision'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 131 (delta 50), reused 108 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (131/131), 271.78 KiB | 11.82 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/DermaVision
# ...
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 5.20G/5.20G [05:10<00:00, 18.0MB/s]
#
# Training will run on device: cuda
# Total mapped dataset samples: 10015
# Train split class counts: [ 890 5364  411  262  879   92  114]
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_s-dd5fe13b.pth
# ...
